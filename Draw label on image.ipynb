# %%
from IP import *
# %matplotlib inline

# %%
data, meta = load_raw_data_with_mhd("/Volumes/JetDrive/dataset/Spine/Raw_data/spine-1/patient0006/4574957/4574957.mhd")
content = read_lml("/Volumes/JetDrive/dataset/Spine/Raw_data/spine-1/patient0006/4574957/4574957.lml")

# %%
im_x, im_y, im_z = convert_coordinate(content, meta)

# %%
psi = dense_label_sagittal(data, im_x, im_y, im_z, 500)
npsi = normalize_dense(psi)

# %%
plt.figure(figsize=(4,7))
plt.scatter(im_y,im_z, color='y', marker='s')
plt.plot(im_y, im_z, color='y')

for i in range(len(content['name'])):
    
    plt.annotate(content['name'][i][0:2], xy=(im_y[i], im_z[i]), 
                xytext=(im_y[i]-50, im_z[i]-5), color='y')

plt.axis('on')
plt.imshow(data[:,:,256], cmap='gray',origin='lower',aspect='auto')
# plt.savefig('/Users/Bato/Dropbox/CSC577/preprocessing_samples/coronal_center.png')

# %%
f, (ax1, ax2) = plt.subplots(1,2)
ax1.imshow(data[:,:,256], cmap='gray',origin='lower')
ax2.imshow(np.argmax(npsi, axis=2), origin='lower')

# %%
print(sys.version)
# Out:
# 2.7.11 |Anaconda 4.0.0 (x86_64)| (default, Dec  6 2015, 18:57:58)
# [GCC 4.2.1 (Apple Inc. build 5577)]
